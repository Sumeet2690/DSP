# %% [markdown]
# <p align="center"><img src="https://github.com/insaid2018/Term-1/blob/master/Images/INSAID_Full%20Logo.png?raw=true" width="260" height="110" /></p>

# %% [markdown]
# ---
# # **Table of Contents**
# ---
#
# 1. [**Introduction**](#Section1)<br>
# 2. [**Problem Statement**](#Section2)<br>
# 3. [**Installing & Importing Libraries**](#Section3)<br>
#   3.1 [**Installing Libraries**](#Section31)<br>
#   3.2 [**Upgrading Libraries**](#Section32)<br>
#   3.3 [**Importing Libraries**](#Section33)<br>
# 4. [**Data Acquisition & Description**](#Section4)<br>
# 5. [**Data Pre-Profiling**](#Section5)<br>
# 6. [**Data Pre-Processing**](#Section6)<br>
# 7. [**Data Post-Profiling**](#Section7)<br>
# 8. [**Exploratory Data Analysis**](#Section8)<br>
# 9. [**Summarization**](#Section9)</br>
#   9.1 [**Conclusion**](#Section91)</br>
#   9.2 [**Actionable Insights**](#Section91)</br>
#
# ---

# %% [markdown]
# ---
# <a name = Section1></a>
# # **1. Introduction**
# ---
#
#
# - The Used Car Market in India is Segmented by Vehicle Type (Hatchbacks, Sedans, and Sports Utility Vehicles), Vendor Type (Organized and Unorganized), and Fuel Type (Petrol and Diesel).
#
# - The Indian used car market was valued at USD 32.14 billion in 2021, and it is expected to reach USD 74.70 billion in 2027, registering a CAGR of 15.1% during the forecast period (2022-2027).
#
# - Reduced cash inflow due to the pandemic has forced buyers to look for alternatives other than new cars, and the used car industry has high growth potential in these terms. As the sales and production of new vehicles have been hindered due to the pandemic, the used car market is gaining traction among buyers.
#
# - Until a few years ago, it was not easy to purchase a luxury car due to its high cost. However, this trend is gradually changing as consumers can now buy pre-owned luxury vehicles. The market is becoming more organized with easy access to financing options, annual maintenance contracts, and lower entry prices. Also, the average age of used luxury vehicles coming into the market is between 2 and 3 years compared to 5-6 years for a mid-size or small-scale vehicle, making them a better option in some cases.
#
# - The market for used cars in India is consolidated, with significant players holding the largest market share due to their business models and increased number of pre-owned car retail outlets. The major players include OLX, Mahindra First Choice Wheels, CARS24, Maruti True Value, and Hyundai H Promise. These players are adopting various growth strategies to stabilize their position in the market.

# %% [markdown]
# ---
# <a name = Section2></a>
# # **2. Problem Statement**
# ---
#
# - This section is emphasised on providing some generic introduction to the problem that most companies confronts.
#
# - **Problem Statement:**
#
#   - In the past few years, prices of new cars have skyrocketed, due to which most people are incapable of buying a new one.
#
#   - Customers buying a new car always looks for assurity of their money to be worthy.
#
#   - But due to the increased price of new cars, used car sales are on a global increase (Pal, Arora and Palakurthy, 2018).
#
#   - There is a need for a used car price prediction system to effectively determine the worthiness of the car using a variety of features.
#
#   - Even though there are websites that offers this service, their prediction method may not be the best.
#
#   - Besides, different models and systems may contribute on predicting power for a used car’s actual market value.
#
#   - It is important to know their actual market value while both buying and selling.
#
# <p align="center"><img src="https://visme.co/blog/wp-content/uploads/2020/06/animated-interactive-infographics-header-wide.gif"></p>
#
# - **Scenario:**
#   - Cars Absolute, an American company buys and sells second hand cars.
#
#   - The company has earned its name because of sincerity in work and quality of services.
#
#   - But for past few months their sales is down for some reason and they are unable to figure it out.
#
#   - To tackle this problem they hired a genius team of data scientists. Consider you are one of them...

# %% [markdown]
# ---
# <a id = Section3></a>
# # **3. Installing & Importing Libraries**
# ---
#
# - This section is emphasised on installing and importing the necessary libraries that will be required.

# %% [markdown]
# ### **Installing Libraries**

# %%
# !pip install -q datascience                              
# !pip install -q pandas-profiling

# %% [markdown]
# ### **Upgrading Libraries**
#
# - **After upgrading** the libraries, you need to **restart the runtime** to make the libraries in sync.
#
# - Make sure not to execute the cell under Installing Libraries and Upgrading Libraries again after restarting the runtime.

# %%
# !pip install -q --upgrade pandas-profiling

# %% [markdown]
# ### **Importing Libraries**
#
# - You can headstart with the basic libraries as imported inside the cell below.
#
# - If you want to import some additional libraries, feel free to do so.

# %%
#-------------------------------------------------------------------------------------------------------------------------------
import pandas as pd                                                 
from pandas_profiling import ProfileReport                          
#-------------------------------------------------------------------------------------------------------------------------------
import numpy as np
import pandas_profiling as pp
#-------------------------------------------------------------------------------------------------------------------------------
import matplotlib.pyplot as plt                                     
import seaborn as sns                                               
# %matplotlib inline
#-------------------------------------------------------------------------------------------------------------------------------
import scipy as sp                                                  
#-------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ---
# <a name = Section4></a>
# # **4. Data Acquisition & Description**
# ---
#
# - This section is emphasised on the accquiring the data and obtain some descriptive information out of it.
#
# - You could either scrap the data and then continue, or use a direct source of link (generally preferred in most cases).
#
# - You will be working with a direct source of link to head start your work without worrying about anything.
#
# - Before going further you must have a good idea about the features of the data set:
#
# |Id|Feature|Description|
# |:--|:--|:--|
# |01| car           | Car brand name|
# |02| model         | Available car different Variants|
# |03| year          | purchasing Year|
# |04| body          | Body type-Hatchback, Sedan, Crossover etc|
# |05| mileage       | car Mileage|
# |06| engV          | Engine version|
# |07| engType       | Car Fuel type - Petrol, Diesel, gas etc|
# |08| drive         | Wheel Drive Front, back|
# |09| registration  | Check if the vechile is registered|
# |10| price         | Price of Car in $|

# %%
data = pd.read_csv(filepath_or_buffer = 'https://raw.githubusercontent.com/insaid2018/Term-1/master/Data/Projects/car_sales.csv', encoding='cp1252')
print('Data Shape:', data.shape)
data.head()
# Out:
# Data Shape: (9576, 10)
#              car    price       body  mileage  engV engType registration  \
# 0           Ford  15500.0  crossover       68   2.5     Gas          yes
# 1  Mercedes-Benz  20500.0      sedan      173   1.8     Gas          yes
# 2  Mercedes-Benz  35000.0      other      135   5.5  Petrol          yes
# 3  Mercedes-Benz  17800.0        van      162   1.8  Diesel          yes
# 4  Mercedes-Benz  33000.0      vagon       91   NaN   Other          yes
#
#    year    model  drive
# 0  2010     Kuga   full
# 1  2011  E-Class   rear
# 2  2008   CL 550   rear
# 3  2012    B 180  front
# 4  2013  E-Class    NaN

# %% [markdown]
# ### **Data Description**
#
# - To get some quick description out of the data you can use describe method defined in pandas library.

# %%
data.describe()
# Out:
#                price      mileage         engV         year
# count    9576.000000  9576.000000  9142.000000  9576.000000
# mean    15633.317316   138.862364     2.646344  2006.605994
# std     24106.523436    98.629754     5.927699     7.067924
# min         0.000000     0.000000     0.100000  1953.000000
# 25%      4999.000000    70.000000     1.600000  2004.000000
# 50%      9200.000000   128.000000     2.000000  2008.000000
# 75%     16700.000000   194.000000     2.500000  2012.000000
# max    547800.000000   999.000000    99.990000  2016.000000

# %% [markdown]
# ### **Data Information**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9576 entries, 0 to 9575
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   car           9576 non-null   object
#  1   price         9576 non-null   float64
#  2   body          9576 non-null   object
#  3   mileage       9576 non-null   int64
#  4   engV          9142 non-null   float64
#  5   engType       9576 non-null   object
#  6   registration  9576 non-null   object
#  7   year          9576 non-null   int64
#  8   model         9576 non-null   object
#  9   drive         9065 non-null   object
# dtypes: float64(2), int64(2), object(6)
# memory usage: 748.2+ KB

# %% [markdown]
# ---
# <a name = Section5></a>
# # **5. Data Pre-Profiling**
# ---
#
# - This section is emphasised on getting a report about the data.
#
# - You need to perform pandas profiling and get some observations out of it...

# %%
profile = pp.ProfileReport(data)
profile.to_file("output.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
data[data.duplicated()] #duplicated data
# Out:
#                 car     price       body  mileage  engV engType registration  \
# 18           Nissan   16600.0  crossover       83   2.0  Petrol          yes
# 42    Mercedes-Benz   20400.0      sedan      190   1.8     Gas          yes
# 70    Mercedes-Benz       0.0  crossover        0   3.0  Diesel          yes
# 86           Toyota  103999.0  crossover        0   4.5  Diesel          yes
# 98    Mercedes-Benz   20400.0      sedan      190   1.8     Gas          yes
# ...             ...       ...        ...      ...   ...     ...          ...
# 9156     Volkswagen   15700.0      sedan      110   1.8  Petrol          yes
# 9163  Mercedes-Benz   20500.0      sedan      222   5.5  Petrol          yes
# 9164            VAZ    3900.0      hatch      121   1.4  Petrol          yes
# 9169        Hyundai   12900.0  crossover       49   2.7  Petrol          yes
# 9477            BMW   77777.0      sedan        8   4.4  Petrol          yes
#
#       year             model  drive
# ...

# %%
(100*(data.shape[0]-data.count())/data.shape[0]).sort_values(ascending = False)  #missing data
# Out:
# drive           5.336257
# engV            4.532164
# car             0.000000
# price           0.000000
# body            0.000000
# mileage         0.000000
# engType         0.000000
# registration    0.000000
# year            0.000000
# model           0.000000
# dtype: float64

# %%
# get all the unique values in the 'car' column
car = data['car'].unique()
# sort them alphabetically and then take a closer look
car.sort()
car
# Out:
# array(['Acura', 'Alfa Romeo', 'Aro', 'Aston Martin', 'Audi', 'BMW', 'BYD',
#        'Barkas', 'Bentley', 'Bogdan', 'Buick', 'Cadillac', 'Changan',
#        'Chery', 'Chevrolet', 'Chrysler', 'Citroen', 'Dacia', 'Dadi',
#        'Daewoo', 'Daihatsu', 'Dodge', 'FAW', 'Ferrari', 'Fiat', 'Fisker',
#        'Ford', 'GAZ', 'GMC', 'Geely', 'Great Wall', 'Groz', 'Hafei',
#        'Honda', 'Huanghai', 'Hummer', 'Hyundai', 'Infiniti', 'Isuzu',
#        'JAC', 'Jaguar', 'Jeep', 'Kia', 'Lamborghini', 'Lancia',
#        'Land Rover', 'Lexus', 'Lifan', 'Lincoln', 'MG', 'MINI',
#        'Maserati', 'Mazda', 'Mercedes-Benz', 'Mercury', 'Mitsubishi',
#        'Moskvich-AZLK', 'Moskvich-Izh', 'Nissan', 'Opel', 'Other-Retro',
#        'Peugeot', 'Porsche', 'Renault', 'Rolls-Royce', 'Rover', 'SMA',
#        'Saab', 'Samand', 'Samsung', 'Seat', 'Skoda', 'Smart', 'SsangYong',
#        'Subaru', 'Suzuki', 'TATA', 'Tesla', 'Toyota', 'UAZ', 'VAZ',
# ...

# %%
# get all the unique values in the 'car' column
body = data['body'].unique()
# sort them alphabetically and then take a closer look
body.sort()
body
# Out:
# array(['crossover', 'hatch', 'other', 'sedan', 'vagon', 'van'],
#       dtype=object)

# %%
engineType = data['engType'].unique()
# sort them alphabetically and then take a closer look
engineType.sort()
engineType
# Out:
# array(['Diesel', 'Gas', 'Other', 'Petrol'], dtype=object)

# %%
drive = data['drive'].unique()
drive
# Out:
# array(['full', 'rear', 'front', nan], dtype=object)

# %%
data[pd.isnull(data['engV'])]    #missing values in 'engV' column
# Out:
#                 car      price   body  mileage  engV engType registration  \
# 4     Mercedes-Benz  33000.000  vagon       91   NaN   Other          yes
# 13              BMW   4700.000  sedan      200   NaN  Petrol          yes
# 30           Nissan  13980.000  hatch       31   NaN   Other          yes
# 31           Nissan  17300.000  hatch       24   NaN   Other          yes
# 37             Audi   2850.000  sedan      260   NaN   Other           no
# ...             ...        ...    ...      ...   ...     ...          ...
# 9470       Chrysler      0.000  vagon      198   NaN  Petrol          yes
# 9480        Renault   8100.000    van      135   NaN  Diesel          yes
# 9515        Renault   5000.000  vagon      150   NaN   Other          yes
# 9546            VAZ    907.725  sedan        1   NaN   Other          yes
# 9566            UAZ    850.000    van      255   NaN   Other          yes
#
#       year         model  drive
# 4     2013       E-Class    NaN
# ...

# %%
df_used_car = pd.DataFrame(data)
sns.boxplot(df_used_car['price'])
# Out:
# C:\Users\saurav\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='price'>

# %%
data['price'].describe()
# Out:
# count      9576.000000
# mean      15633.317316
# std       24106.523436
# min           0.000000
# 25%        4999.000000
# 50%        9200.000000
# 75%       16700.000000
# max      547800.000000
# Name: price, dtype: float64

# %%
Q1 = data['price'].quantile(0.25)
Q3 = data['price'].quantile(0.75)
IQR = Q3- Q1
low_lim = Q1 - 1.5 * IQR
higher_lim = Q3 + 1.5 * IQR
low_lim
# Out:
# -12552.5

# %%
higher_lim
# Out:
# 34251.5

# %%
low_lim_cnt = (data['price'] < low_lim)

# %%
high_lim_cnt = (data['price'] > higher_lim)

# %%
data['price'][high_lim_cnt]
# Out:
# 2        35000.0
# 16      129222.0
# 17       99999.0
# 19       73900.0
# 22      104999.0
#           ...
# 9477     77777.0
# 9492     67900.0
# 9523     43000.0
# 9548     34600.0
# 9550     44800.0
# Name: price, Length: 899, dtype: float64

# %%
data['Years_in_Service'] = 2022 - data['year']

# %%
data2 = data.loc[(high_lim_cnt,['car','model','Years_in_Service','price'])].groupby(['car','model','Years_in_Service'])['price'].mean().sort_values()

# %%
data3 = data.loc[(high_lim_cnt,['car','model','Years_in_Service'])].value_counts()

# %%
data[(data.car=="Tesla") & (data.model=='Model S') & (data.Years_in_Service==9)].mean()
# Out:
# C:\Users\saurav\AppData\Local\Temp\ipykernel_5912\1326011271.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data[(data.car=="Tesla") & (data.model=='Model S') & (data.Years_in_Service==9)].mean()
# price               61850.000
# mileage                28.875
# engV                    0.550
# year                 2013.000
# Years_in_Service        9.000
# dtype: float64

# %%
data[(data.car=="Tesla") & (data.price==80000.00)]
# Out:
#        car    price   body  mileage  engV engType registration  year    model  \
# 316  Tesla  80000.0  sedan       27   NaN   Other          yes  2013  Model S
#
#      drive  Years_in_Service
# 316  front                 9

# %%
data[(data.car=="Tesla") & (data.model=='Model S') & (data.Years_in_Service==9) & (data.price==80000.00)]['price'].replace(80000,61850)
# Out:
# 316    61850.0
# Name: price, dtype: float64

# %%
data[(data.car=="Land Rover") & (data.model=='Range Rover') & (data.engV==5)]['price'].mean()
# Out:
# 67788.70833333333

# %%
data[(data.car=="Land Rover") & (data.model=='Range Rover') & (data.engV==5)]['price'].max()
# Out:
# 285000.0

# %%
data[(data.car=="Land Rover") & (data.model=='Range Rover') & (data.engV==5)& (data.price==285000)]
# Out:
#              car     price       body  mileage  engV engType registration  \
# 8205  Land Rover  285000.0  crossover        0   5.0  Petrol          yes
#
#       year        model drive  Years_in_Service
# 8205  2016  Range Rover  full                 6

# %%
data[(data.car=="Land Rover") & (data.model=='Range Rover') & (data.engV==5) & (data.mileage<10)]
# Out:
#              car     price       body  mileage  engV engType registration  \
# 4489  Land Rover  106000.0  crossover        9   5.0  Petrol          yes
# 6723  Land Rover       0.0  crossover        1   5.0  Petrol          yes
# 8205  Land Rover  285000.0  crossover        0   5.0  Petrol          yes
#
#       year        model drive  Years_in_Service
# 4489  2013  Range Rover  full                 9
# 6723  2016  Range Rover  full                 6
# 8205  2016  Range Rover  full                 6

# %%
data[(data.car=="Land Rover") & (data.model=='Range Rover') & (data.engV==5)& (data.price==285000)]['price'].replace(285000,106000)
# Out:
# 8205    106000.0
# Name: price, dtype: float64

# %%
data[(data.car=="Porsche") & (data.model=='Cayenne') & (data.mileage<40) & (data.engV == 4.8)]
# Out:
#           car     price       body  mileage  engV engType registration  year  \
# 76    Porsche  114900.0  crossover       25   4.8  Petrol          yes  2013
# 224   Porsche   81000.0  crossover       35   4.8  Petrol          yes  2014
# 7507  Porsche   68000.0  crossover       38   4.8  Petrol          yes  2012
#
#         model drive  Years_in_Service
# 76    Cayenne  full                 9
# 224   Cayenne  full                 8
# 7507  Cayenne  full                10

# %%
data[(data.car=="Porsche") & (data.model=='Cayenne') & (data.mileage<40) & (data.price!=0)].mean()
# Out:
# C:\Users\saurav\AppData\Local\Temp\ipykernel_5912\1364860608.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data[(data.car=="Porsche") & (data.model=='Cayenne') & (data.mileage<40) & (data.price!=0)].mean()
# price               86614.000000
# mileage                18.714286
# engV                    3.855714
# year                 2014.285714
# Years_in_Service        7.714286
# dtype: float64

# %%
data[(data.car=="Porsche") & (data.model=='Cayenne') & (data.mileage<40) & (data.price==114900)]['price'].replace(114900,86614)
# Out:
# 76    86614.0
# Name: price, dtype: float64

# %%
data[(data.car=="Land Rover") & (data.model=='Range Rover Sport') & (data.engV > 2.99) & (data.engV < 3.61) & (data.engType == 'Diesel')& data.price !=0]['price'].mean()
# Out:
# 55282.730769230766

# %%
data[(data.car=="Land Rover") & (data.model=='Range Rover Sport') & (data.engV > 2.99) &(data.engType == 'Diesel')& (data.engV < 3.61) & data.price !=0]['price'].describe()
# Out:
# count        26.000000
# mean      55282.730769
# std       25273.927811
# min       12999.000000
# 25%       32475.000000
# 50%       53500.000000
# 75%       77675.000000
# max      109999.000000
# Name: price, dtype: float64

# %%
data[(data.car=="Land Rover") & (data.model=='Range Rover Sport') & (data.engType == "Diesel") & (data.engV > 2.99) & (data.engV < 3.61) & (data.price >80000)]['price'].replace([85900,95555,89900,109999],95000)
# Out:
# 541     95000.0
# 3283    95000.0
# 6439    95000.0
# 8211    95000.0
# Name: price, dtype: float64

# %%
data[(data.car=="Land Rover") & (data.model=='Range Rover Sport') & (data.engV ==5) & (data.engType == 'Petrol')& data.price !=0]['price'].mean()
# Out:
# 62299.933333333334

# %%
data[(data.car=="Land Rover") & (data.model=='Range Rover Sport') & (data.engV ==5) & (data.engType == 'Petrol')& data.price !=0]['price'].describe()
# Out:
# count        15.000000
# mean      62299.933333
# std       32052.528985
# min       32500.000000
# 25%       38850.000000
# 50%       49800.000000
# 75%       80500.000000
# max      147000.000000
# Name: price, dtype: float64

# %%
data[(data.car=="Land Rover") & (data.model=='Range Rover Sport') & (data.engV ==5) & (data.engType == 'Petrol')& (data.price > 95000)]
# Out:
#             car     price       body  mileage  engV engType registration  \
# 266  Land Rover  147000.0  crossover       15   5.0  Petrol          yes
#
#      year              model drive  Years_in_Service
# 266  2015  Range Rover Sport  full                 7

# %%
sns.boxplot(df_used_car['mileage'])
# Out:
# C:\Users\saurav\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='mileage'>

# %%
data['mileage'].describe()
# Out:
# count    9576.000000
# mean      138.862364
# std        98.629754
# min         0.000000
# 25%        70.000000
# 50%       128.000000
# 75%       194.000000
# max       999.000000
# Name: mileage, dtype: float64

# %%
data['engV'].describe()
# Out:
# count    9142.000000
# mean        2.646344
# std         5.927699
# min         0.100000
# 25%         1.600000
# 50%         2.000000
# 75%         2.500000
# max        99.990000
# Name: engV, dtype: float64

# %%
sns.boxplot(x = data['engV'])
# Out:
# <AxesSubplot:xlabel='engV'>

# %%
Q1 = data['engV'].quantile(0.25)
Q3 = data['engV'].quantile(0.75)
IQR = Q3- Q1
lower_lim = Q1 - 1.5 * IQR
high_lim = Q3 + 4.5 * IQR
lower_lim
# Out:
# 0.2500000000000002

# %%
high_lim
# Out:
# 6.55

# %%
lower_lim_cnt = (data['engV'] < lower_lim)

# %%
higher_lim_cnt = (data['engV'] > high_lim)

# %%
data = data[~(lower_lim_cnt|higher_lim_cnt)]

# %%
sns.boxplot(x = data['engV'])
# Out:
# <AxesSubplot:xlabel='engV'>

# %% [markdown]
# ---
# <a name = Section6></a>
# # **6. Data Pre-Processing**
# ---
#
# - This section is emphasised on performing data manipulation over unstructured data for further processing and analysis.
#
# - To modify unstructured data to strucuted data you need to verify and manipulate the integrity of the data by:
#   - Handling missing data,
#
#   - Handling redundant data,
#
#   - Handling inconsistent data,
#
#   - Handling outliers,
#
#   - Handling typos

# %%
'''
Handling Duplicated Data
'''
# Out:
# '\nHandling Duplicated Data\n'

# %%
data.drop_duplicates(keep=False, inplace=True) #Removing Duplicates
# Out:
# C:\Users\saurav\AppData\Local\Temp\ipykernel_5912\3737925206.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop_duplicates(keep=False, inplace=True) #Removing Duplicates

# %%
'''
Filling blanks in 'engV' column
'''
# Out:
# "\nFilling blanks in 'engV' column\n"

# %%
data2 = data[pd.isnull(data['engV'])]

# %%
data3=pd.merge(data, data2, on =['car','engType','model'], how='right')

# %%
data4 = data3.loc[:,['car','model','engType','engV_x']]

# %%
data4.drop_duplicates(inplace=True)

# %%
data4 = data4[~data4['engV_x'].isna()].drop_duplicates(subset=['car','model','engType'])

# %%
data4.rename(columns = {'engV_x':'engV'}, inplace = True)

# %%
data = data.merge(data4,how='left',left_on=['car','model','engType'],right_on=['car','model','engType'])

# %%
data['engV_x']=data['engV_x'].fillna(data['engV_y'])

# %%
data = data.drop("engV_y",axis = 1)

# %%
data.rename(columns = {'engV_x':'engV'}, inplace = True)

# %%
data[data['engV'].isna()]
# Out:
#                 car      price       body  mileage  engV engType registration  \
# 115   Mercedes-Benz  93555.000  crossover        0   NaN   Other          yes
# 179         Hyundai  10500.000  crossover      120   NaN   Other          yes
# 291          Toyota  36000.000  crossover      940   NaN   Other          yes
# 764             BMW  45000.000      sedan      110   NaN   Other          yes
# 818             VAZ   1850.000      sedan       60   NaN   Other          yes
# ...             ...        ...        ...      ...   ...     ...          ...
# 9085         Barkas   5500.000        van       80   NaN  Petrol          yes
# 9108            BMW   5500.000      sedan      249   NaN   Other          yes
# 9144            BMW   6800.000      sedan      325   NaN   Other           no
# 9268            VAZ    907.725      sedan        1   NaN   Other          yes
# 9288            UAZ    850.000        van      255   NaN   Other          yes
#
# ...

# %%
'''
Filling missing values for drive column
'''
# Out:
# '\nFilling missing values for drive column\n'

# %%
data2 = data[pd.isnull(data['drive'])]

# %%
data3=pd.merge(data, data2, on =['car','engType','model','body'], how='right')

# %%
data4 = data3.loc[:,['car','model','engType','body','drive_x']]

# %%
data4.drop_duplicates(inplace=True)

# %%
data4 = data4[~data4['drive_x'].isna()].drop_duplicates(subset=['car','model','engType','body'])

# %%
data4.rename(columns = {'drive_x':'drive'}, inplace = True)

# %%
data = data.merge(data4,how='left',left_on=['car','model','engType','body'],right_on=['car','model','engType','body'])

# %%
data['drive_x']=data['drive_x'].fillna(data['drive_y'])

# %%
data = data.drop("drive_y",axis = 1)

# %%
data.rename(columns = {'drive_x':'drive'}, inplace = True)

# %%
data[data['drive'].isna()]
# Out:
#                 car     price       body  mileage  engV engType registration  \
# 1     Mercedes-Benz  33000.00      vagon       91   2.2   Other          yes
# 115   Mercedes-Benz  93555.00  crossover        0   NaN   Other          yes
# 291          Toyota  36000.00  crossover      940   NaN   Other          yes
# 753      Volkswagen  13700.00      other      103   2.0  Diesel          yes
# 775      Great Wall  10500.00      other       32   2.0  Petrol          yes
# ...             ...       ...        ...      ...   ...     ...          ...
# 9016           Ford   5700.00      other      100   NaN   Other          yes
# 9085         Barkas   5500.00        van       80   NaN  Petrol          yes
# 9123           ËUAZ   1296.75      other       30   1.2  Petrol          yes
# 9144            BMW   6800.00      sedan      325   NaN   Other           no
# 9288            UAZ    850.00        van      255   NaN   Other          yes
#
# ...

# %%
'''
Handling Typos
'''
# Out:
# '\nHandling Typos\n'

# %%
data['model']= data['model'].replace('9-May','9-5') #Data Type Correction Earlier date was entered now model is replaced fro Saab

# %%
'''
Dropping rows having zero in price column
'''
# Out:
# '\nDropping rows having zero in price column\n'

# %%
data = data.loc[~(data.price==0)]

# %%
data = data.dropna(subset=['engV','drive'])

# %% [markdown]
# ---
# <a name = Section7></a>
# # **7. Data Post-Profiling**
# ---
#
# - This section is emphasised on getting a report about the data after the data manipulation.
#
# - You may end up observing some new changes, so keep it under check and make right observations.

# %%
data[pd.isnull(data['drive'])].count()
# Out:
# car                 0
# price               0
# body                0
# mileage             0
# engV                0
# engType             0
# registration        0
# year                0
# model               0
# drive               0
# Years_in_Service    0
# dtype: int64

# %%
data[pd.isnull(data['engV'])].count()
# Out:
# car                 0
# price               0
# body                0
# mileage             0
# engV                0
# engType             0
# registration        0
# year                0
# model               0
# drive               0
# Years_in_Service    0
# dtype: int64

# %%
data[data.duplicated()] #Duplicates Removed
# Out:
#              car    price       body  mileage  engV engType registration  \
# 2019  Mitsubishi  19400.0  crossover       78   2.4  Petrol          yes
# 3490         BMW  77500.0  crossover        1   3.0  Petrol          yes
#
#       year         model drive  Years_in_Service
# 2019  2012  Outlander XL  full                10
# 3490  2016            X6  full                 6

# %%
profile = pp.ProfileReport(data)
profile.to_file("output1.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
data.to_csv('data_cleaned.csv')

# %%
# Insert your code here...

# %% [markdown]
# ---
# <a name = Section8></a>
# # **8. Exploratory Data Analysis**
# ---
#
# - This section is emphasised on asking the right questions and perform analysis using the data.
#
# - Note that there is no limit how deep you can go, but make sure not to get distracted from right track.

# %%
# Insert your code here...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8906 entries, 0 to 9297
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car               8906 non-null   object
#  1   price             8906 non-null   float64
#  2   body              8906 non-null   object
#  3   mileage           8906 non-null   int64
#  4   engV              8906 non-null   float64
#  5   engType           8906 non-null   object
#  6   registration      8906 non-null   object
#  7   year              8906 non-null   int64
#  8   model             8906 non-null   object
#  9   drive             8906 non-null   object
#  10  Years_in_Service  8906 non-null   int64
# dtypes: float64(2), int64(3), object(6)
# memory usage: 1.1+ MB

# %%
data.describe()
# Out:
#                price      mileage         engV         year  Years_in_Service
# count    8906.000000  8906.000000  8906.000000  8906.000000       8906.000000
# mean    15326.989836   141.814170     2.194573  2006.488772         15.511228
# std     21419.740309    97.414461     0.937929     6.865511          6.865511
# min       259.350000     0.000000     0.600000  1959.000000          6.000000
# 25%      5400.000000    74.000000     1.600000  2004.000000         11.000000
# 50%      9400.000000   130.000000     2.000000  2008.000000         14.000000
# 75%     16700.000000   197.000000     2.500000  2011.000000         18.000000
# max    449999.000000   999.000000     6.500000  2016.000000         63.000000

# %%
data['Years_in_Service'].describe()
# Out:
# count    8906.000000
# mean       15.511228
# std         6.865511
# min         6.000000
# 25%        11.000000
# 50%        14.000000
# 75%        18.000000
# max        63.000000
# Name: Years_in_Service, dtype: float64

# %%
data['body'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
sns.set(rc={"figure.figsize": (12,12)});
sns.displot(data.price,kde=False)

# %%
sns.displot(data['mileage'],kde=False,bins=50)

# %%
data['car'].value_counts().nlargest(17)
# Out:
# Volkswagen       875
# Mercedes-Benz    798
# BMW              631
# Toyota           507
# VAZ              463
# Renault          444
# Audi             431
# Opel             385
# Skoda            353
# Hyundai          350
# Nissan           349
# Ford             321
# Mitsubishi       312
# Chevrolet        239
# Daewoo           221
# Kia              210
# Honda            199
# Name: car, dtype: int64

# %%
data['car'].value_counts().nlargest(17).sort_values(ascending = False).plot.bar()
# Out:
# <AxesSubplot:>

# %%
plt.scatter(data.engV, data.price)
plt.title('Price vs. engine Version')
plt.xlabel('engine Version')
plt.ylabel('Car Price')
# Out:
# Text(0, 0.5, 'Car Price')

# %%
data.groupby('Years_in_Service').agg({'price':'mean'}).plot.bar()
# Out:
# <AxesSubplot:xlabel='Years_in_Service'>

# %%
data.loc[(data.Years_in_Service > 0) & (data.Years_in_Service < 15)].groupby('body').agg({'price':'mean'}).plot.bar()
# Out:
# <AxesSubplot:xlabel='body'>

# %%
data.loc[(data.Years_in_Service > 15) & (data.Years_in_Service < 25)].groupby('body').agg({'price':'mean'}).plot.bar()
# Out:
# <AxesSubplot:xlabel='body'>

# %%
data.loc[(data.Years_in_Service > 25) & (data.Years_in_Service < 40)].groupby('body').agg({'price':'mean'}).plot.bar()
# Out:
# <AxesSubplot:xlabel='body'>

# %%
data.loc[(data.Years_in_Service > 40)].groupby('body').agg({'price':'mean'}).plot.bar()
# Out:
# <AxesSubplot:xlabel='body'>

# %%
drive_analysis = data.groupby(['engType'])['price'].mean()
drive_analysis.plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='engType'>

# %%
drive_analysis = data.groupby(['body'])['mileage'].mean()
drive_analysis.plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='body'>

# %%
drive_analysis = data.groupby(['car'])['price'].mean().nlargest(10)
data['car_brand_mean_price'] = data.groupby(['car'],sort=False)['price'].transform('mean')
drive_analysis.plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='car'>

# %%
def categorise(row):
    if row['car_brand_mean_price'] > 0 and row['car_brand_mean_price'] < (data['price'].quantile(0.25)):
        return 'economy'
    elif row['car_brand_mean_price'] >= (data['price'].quantile(0.25)) and row['car_brand_mean_price'] < (data['price'].quantile(0.75)):
        return 'premium'
    return 'luxury'

# %%
data['car_category'] = data.apply(lambda row: categorise(row), axis = 1)

# %%
data['car_category'].value_counts()/data['car'].count()*100
# Out:
# premium    56.669661
# luxury     33.056366
# economy    10.273973
# Name: car_category, dtype: float64

# %%
data.corr()
# Out:
#                          price   mileage      engV      year  \
# price                 1.000000 -0.334819  0.494984  0.408209
# mileage              -0.334819  1.000000  0.060486 -0.501932
# engV                  0.494984  0.060486  1.000000  0.041266
# year                  0.408209 -0.501932  0.041266  1.000000
# Years_in_Service     -0.408209  0.501932 -0.041266 -1.000000
# car_brand_mean_price  0.525442  0.029269  0.554856  0.098335
#
#                       Years_in_Service  car_brand_mean_price
# price                        -0.408209              0.525442
# mileage                       0.501932              0.029269
# engV                         -0.041266              0.554856
# year                         -1.000000              0.098335
# Years_in_Service              1.000000             -0.098335
# car_brand_mean_price         -0.098335              1.000000

# %%
pd.crosstab(data['body'],data['engType'])
# Out:
# engType    Diesel  Gas  Other  Petrol
# body
# crossover     657  410     29     769
# hatch         126  190    105     774
# other         273   78     30     365
# sedan         496  836    134    1986
# vagon         367   90     21     200
# van           840   48     19      63

# %%
min_value = data['mileage'].min()
max_value = data['mileage'].max()
print(min_value)
print(max_value)
# Out:
# 0
# 999

# %%
bins = np.linspace(min_value,max_value,8)
bins
# Out:
# array([  0.        , 142.71428571, 285.42857143, 428.14285714,
#        570.85714286, 713.57142857, 856.28571429, 999.        ])

# %%
labels = ['new','rarely used', 'somewhat used', 'moderately used', 'used', 'rigourously used', 'junk']

# %%
data['bins'] = pd.cut(data['mileage'], bins=bins, labels=labels, include_lowest=True)

# %%
others = data.loc[data.body=='other']

# %%
min_value_age = data['Years_in_Service'].min()
max_value_age = data['Years_in_Service'].max()
print(min_value)
print(max_value)
# Out:
# 0
# 999

# %%
bin_age = np.linspace(6,63,8)
bin_age
# Out:
# array([ 6.        , 14.14285714, 22.28571429, 30.42857143, 38.57142857,
#        46.71428571, 54.85714286, 63.        ])

# %%
label_age = ['6-14','15-23', '24-32', '33-41', '42-50', '51-59', '60-68']

# %%
data['age_bins'] = pd.cut(data['Years_in_Service'], bins=bin_age, labels=label_age, include_lowest=True)

# %%
sedan = data.loc[data.body=='sedan']

# %%
vagon = data.loc[data.body=='vagon']

# %%
van = data.loc[data.body=='van']

# %%
hatch = data.loc[(data.body=='hatch')]

# %%
crossover=data.loc[data.body=='crossover']

# %%
economy = data.loc[(data.car_category) == 'economy']

# %%
economy['car'].value_counts()
# Out:
# VAZ              463
# Daewoo           221
# ZAZ               97
# Chery             52
# GAZ               22
# UAZ               18
# Dacia             10
# Moskvich-AZLK      8
# Moskvich-Izh       4
# ËUAZ               4
# Lifan              3
# Groz               2
# Lancia             2
# Bogdan             2
# Samand             2
# FAW                1
# Aro                1
# SMA                1
# Wartburg           1
# Buick              1
# Name: car, dtype: int64

# %%
economy['body'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
plt.hist(economy['Years_in_Service'], bins=7)
# Out:
# (array([331., 368.,  73.,  91.,  40.,   7.,   5.]),
#  array([ 6.        , 14.14285714, 22.28571429, 30.42857143, 38.57142857,
#         46.71428571, 54.85714286, 63.        ]),
#  <BarContainer object of 7 artists>)

# %%
economy.set_index('age_bins', inplace=True)
economy.groupby(['age_bins'])['price'].mean().plot(legend =  True)
# Out:
# <AxesSubplot:xlabel='age_bins'>

# %%
economy
# Out:
#              car   price   body  mileage  engV engType registration  year  \
# age_bins
# 15-23     Daewoo  3500.0  sedan      112   1.5  Petrol          yes  2007
# 15-23     Daewoo  4300.0  sedan       70   1.5  Petrol          yes  2007
# 6-14      Daewoo  5600.0  sedan      145   1.6  Petrol          yes  2008
# 15-23     Daewoo  3200.0  sedan      130   1.5  Petrol          yes  2003
# 15-23        VAZ  3600.0  other       80   2.0     Gas          yes  2002
# ...          ...     ...    ...      ...   ...     ...          ...   ...
# 6-14      Daewoo  4400.0  sedan       87   1.6  Petrol          yes  2008
# 15-23        VAZ  2350.0  sedan       11   1.5  Petrol          yes  2006
# 51-59        VAZ   750.0  sedan       20   1.5  Petrol          yes  1975
# 15-23        VAZ  2750.0  sedan      130   1.5     Gas          yes  2007
# 15-23        ZAZ  2100.0  sedan       68   1.2  Petrol          yes  2006
#
# ...

# %%
premium = data.loc[(data.car_category) == 'premium']

# %%
premium['car'].value_counts()
# Out:
# Volkswagen    875
# Renault       444
# Opel          385
# Skoda         353
# Hyundai       350
# Nissan        349
# Ford          321
# Mitsubishi    312
# Chevrolet     239
# Kia           210
# Honda         199
# Mazda         190
# Peugeot       176
# Fiat          115
# Subaru        106
# Citroen        99
# Suzuki         55
# Geely          55
# Smart          54
# SsangYong      45
# Seat           37
# Chrysler       23
# Alfa Romeo     11
# Great Wall      8
# BYD             7
# Lincoln         6
# MG              4
# Rover           4
# Daihatsu        3
# Dadi            2
# JAC             2
# Hafei           1
# Isuzu           1
# Samsung         1
# TATA            1
# Saab            1
# Mercury         1
# ZX              1
# Huanghai        1
# Name: car, dtype: int64

# %%
premium['body'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
plt.hist(premium['Years_in_Service'], bins=7)
# Out:
# (array([1761., 2180.,  616.,  255.,  176.,   54.,    5.]),
#  array([ 6.        , 11.71428571, 17.42857143, 23.14285714, 28.85714286,
#         34.57142857, 40.28571429, 46.        ]),
#  <BarContainer object of 7 artists>)

# %%
premium.set_index('age_bins', inplace=True)
premium.groupby(['age_bins'])['price'].mean().plot(legend =  True)
# Out:
# <AxesSubplot:xlabel='age_bins'>

# %%
luxury = data.loc[(data.car_category) == 'luxury']

# %%
luxury['car'].value_counts()
# Out:
# Mercedes-Benz    798
# BMW              631
# Toyota           507
# Audi             431
# Lexus            163
# Land Rover       126
# Porsche           71
# Infiniti          60
# Volvo             31
# Jeep              25
# Jaguar            18
# Tesla             18
# MINI              15
# Acura             13
# Dodge             12
# Bentley            9
# Hummer             4
# Cadillac           3
# Aston Martin       3
# GMC                2
# Ferrari            2
# Maserati           1
# Lamborghini        1
# Name: car, dtype: int64

# %%
luxury['body'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
plt.hist(luxury['Years_in_Service'], bins=7)
# Out:
# (array([921., 919., 665., 289.,  99.,  42.,   9.]),
#  array([ 6.        , 11.42857143, 16.85714286, 22.28571429, 27.71428571,
#         33.14285714, 38.57142857, 44.        ]),
#  <BarContainer object of 7 artists>)

# %%
luxury.set_index('age_bins', inplace=True)
luxury.groupby(['age_bins'])['price'].mean().plot(legend =  True)
# Out:
# <AxesSubplot:xlabel='age_bins'>

# %%
plt.figure(figsize=(9,7))
plt.hist(crossover['age_bins'], bins=7)
# Out:
# (array([1.291e+03, 5.100e+02, 4.100e+01, 0.000e+00, 1.000e+01, 1.200e+01,
#         1.000e+00]),
#  array([0.        , 0.71428571, 1.42857143, 2.14285714, 2.85714286,
#         3.57142857, 4.28571429, 5.        ]),
#  <BarContainer object of 7 artists>)

# %%
plt.figure(figsize=(9,7))
plt.hist(sedan['age_bins'], bins=7)
# Out:
# (array([1266., 1509.,  431.,  200.,   37.,    6.,    3.]),
#  array([0.        , 0.85714286, 1.71428571, 2.57142857, 3.42857143,
#         4.28571429, 5.14285714, 6.        ]),
#  <BarContainer object of 7 artists>)

# %%
plt.figure(figsize=(9,7))
plt.hist(hatch['age_bins'], bins=7)
# Out:
# (array([669., 334., 110.,   0.,  80.,   1.,   1.]),
#  array([0.        , 0.71428571, 1.42857143, 2.14285714, 2.85714286,
#         3.57142857, 4.28571429, 5.        ]),
#  <BarContainer object of 7 artists>)

# %%
plt.figure(figsize=(9,7))
plt.hist(van['age_bins'], bins=7)
# Out:
# (array([496.,   0., 399.,   0.,  67.,   0.,   8.]),
#  array([0.        , 0.42857143, 0.85714286, 1.28571429, 1.71428571,
#         2.14285714, 2.57142857, 3.        ]),
#  <BarContainer object of 7 artists>)

# %%
plt.figure(figsize=(9,7))
plt.hist(vagon['age_bins'], bins=7)
# Out:
# (array([ 84., 280.,   0., 292.,   0.,  18.,   4.]),
#  array([0.        , 0.57142857, 1.14285714, 1.71428571, 2.28571429,
#         2.85714286, 3.42857143, 4.        ]),
#  <BarContainer object of 7 artists>)

# %%
plt.figure(figsize=(9,7))
plt.hist(crossover['bins'], bins=7)
# Out:
# (array([1.347e+03, 4.870e+02, 2.000e+00, 0.000e+00, 1.000e+00, 2.700e+01,
#         1.000e+00]),
#  array([0.        , 0.71428571, 1.42857143, 2.14285714, 2.85714286,
#         3.57142857, 4.28571429, 5.        ]),
#  <BarContainer object of 7 artists>)

# %%
plt.figure(figsize=(9,7))
plt.hist(sedan['bins'], bins=7)
# Out:
# (array([1268., 1840.,  311.,    3.,    3.,   25.,    2.]),
#  array([0.        , 0.85714286, 1.71428571, 2.57142857, 3.42857143,
#         4.28571429, 5.14285714, 6.        ]),
#  <BarContainer object of 7 artists>)

# %%
plt.figure(figsize=(9,7))
plt.hist(hatch['bins'],bins =7)
# Out:
# (array([865., 283.,  36.,   2.,   6.,   2.,   1.]),
#  array([0.        , 0.85714286, 1.71428571, 2.57142857, 3.42857143,
#         4.28571429, 5.14285714, 6.        ]),
#  <BarContainer object of 7 artists>)

# %%
plt.hist(van['bins'],bins =7)
# Out:
# (array([258., 592., 105.,   0.,  12.,   2.,   1.]),
#  array([0.        , 0.71428571, 1.42857143, 2.14285714, 2.85714286,
#         3.57142857, 4.28571429, 5.        ]),
#  <BarContainer object of 7 artists>)

# %%
plt.hist(vagon['bins'],bins =7)
# Out:
# (array([378.,   0.,  63.,   0., 233.,   0.,   4.]),
#  array([0.        , 0.42857143, 0.85714286, 1.28571429, 1.71428571,
#         2.14285714, 2.57142857, 3.        ]),
#  <BarContainer object of 7 artists>)

# %%
hatch.set_index('age_bins', inplace=True)
hatch.groupby(['age_bins'])['price'].mean().plot(legend =  True)
# Out:
# <AxesSubplot:xlabel='age_bins'>

# %%
sedan.set_index('age_bins', inplace=True)
sedan.groupby(['age_bins'])['price'].mean().plot(legend =  True)
# Out:
# <AxesSubplot:xlabel='age_bins'>

# %%
crossover.set_index('age_bins', inplace=True)
crossover.groupby(['age_bins'])['price'].mean().plot(legend =  True)
# Out:
# <AxesSubplot:xlabel='age_bins'>

# %%
van.set_index('age_bins', inplace=True)
van.groupby(['age_bins'])['price'].mean().plot(legend =  True)
# Out:
# <AxesSubplot:xlabel='age_bins'>

# %%
others.set_index('age_bins', inplace=True)
others.groupby(['age_bins'])['price'].mean().plot(legend =  True)
# Out:
# <AxesSubplot:xlabel='age_bins'>

# %%
vagon.set_index('age_bins', inplace=True)
vagon.groupby(['age_bins'])['price'].mean().plot(legend =  True)
# Out:
# <AxesSubplot:xlabel='age_bins'>

# %%
plt.hist(data['drive'])
# Out:
# (array([1366.,    0.,    0.,    0.,    0., 5246.,    0.,    0.,    0.,
#         2294.]),
#  array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. ]),
#  <BarContainer object of 10 artists>)

# %%
data.groupby('drive')['price'].mean().plot(legend =  True)
# Out:
# <AxesSubplot:xlabel='drive'>

# %%
crossover['drive'].value_counts().plot()
# Out:
# <AxesSubplot:>

# %%
sedan['drive'].value_counts().plot()
# Out:
# <AxesSubplot:>

# %%
hatch['drive'].value_counts().plot()
# Out:
# <AxesSubplot:>

# %%
others['drive'].value_counts().plot()
# Out:
# <AxesSubplot:>

# %%
van['drive'].value_counts().plot()
# Out:
# <AxesSubplot:>

# %%
vagon['drive'].value_counts().plot()
# Out:
# <AxesSubplot:>

# %%
economy['drive'].value_counts().plot()
# Out:
# <AxesSubplot:>

# %%
premium['drive'].value_counts().plot()
# Out:
# <AxesSubplot:>

# %%
luxury['drive'].value_counts().plot()
# Out:
# <AxesSubplot:>

# %%
economy.groupby(['car'])['model'].nunique().mean()
# Out:
# 4.7

# %%
premium.groupby(['car'])['model'].nunique().mean()
# Out:
# 11.35897435897436

# %%
luxury.groupby(['car'])['model'].nunique().mean()
# Out:
# 14.0

# %%
data
# Out:
#                 car      price       body  mileage  engV engType registration  \
# 0     Mercedes-Benz  35000.000      other      135   5.5  Petrol          yes
# 2             Honda   6500.000      sedan      199   2.0  Petrol          yes
# 3     Mercedes-Benz  21500.000      sedan      146   1.8     Gas          yes
# 4     Mercedes-Benz  22700.000      sedan      125   2.2  Diesel          yes
# 5            Nissan  20447.154  crossover        0   1.2  Petrol          yes
# ...             ...        ...        ...      ...   ...     ...          ...
# 9293        Hyundai  14500.000  crossover      140   2.0     Gas          yes
# 9294     Volkswagen   2200.000      vagon      150   1.6  Petrol          yes
# 9295  Mercedes-Benz  18500.000  crossover      180   3.5  Petrol          yes
# 9296          Lexus  16999.000      sedan      150   3.5     Gas          yes
# 9297           Audi  22500.000      other       71   3.6  Petrol          yes
#
# ...

# %%
data.loc[(data.age_bins == '6-14')].groupby('engV').agg({'engV':'count'}).plot.bar()
# Out:
# <AxesSubplot:xlabel='engV'>

# %%
data.loc[(data.age_bins == '15-23')].groupby('engV').agg({'engV':'count'}).plot.bar()
# Out:
# <AxesSubplot:xlabel='engV'>

# %%
data.loc[(data.age_bins == '24-32')].groupby('engV').agg({'engV':'count'}).plot.bar()
# Out:
# <AxesSubplot:xlabel='engV'>

# %%
data.loc[(data.age_bins == '33-41')].groupby('engV').agg({'engV':'count'}).plot.bar()
# Out:
# <AxesSubplot:xlabel='engV'>

# %%
#data.set_index('age_bins', inplace=True)
data.loc[(data.age_bins == '42-50')].groupby('engV').agg({'engV':'count'}).plot.bar()
# Out:
# <AxesSubplot:xlabel='engV'>

# %%
data.loc[(data.age_bins == '51-59')].groupby('engV').agg({'engV':'count'}).plot.bar()
# Out:
# <AxesSubplot:xlabel='engV'>

# %%
data.loc[(data.age_bins == '60-68')].groupby('engV').agg({'engV':'count'}).plot.bar()
# Out:
# <AxesSubplot:xlabel='engV'>

# %%
data = data.drop(['age_bins'],axis =1)

# %%
min_value_engV = data['engV'].min()
max_value_engV = data['engV'].max()
print(min_value_engV)
print(max_value_engV)
# Out:
# 0.6
# 6.5

# %%
bin_engV = [0.6,2,3.5,6.5]
labels_engV = ['small', 'medium','large']
data['engV_bins'] = pd.cut(data['engV'], bins=bin_engV, labels=labels_engV, include_lowest=True)

# %%
data['engV_bins'].value_counts()
# Out:
# small     5637
# medium    2560
# large      709
# Name: engV_bins, dtype: int64

# %%
data.groupby('engV_bins')['mileage'].mean().plot(legend =  True)
# Out:
# <AxesSubplot:xlabel='engV_bins'>

# %%
data.loc[(data.engV_bins == 'small')].groupby('body').agg({'body':'count'}).plot.bar()
# Out:
# <AxesSubplot:xlabel='body'>

# %%
data.loc[(data.engV_bins == 'medium')].groupby('body').agg({'body':'count'}).plot.bar()
# Out:
# <AxesSubplot:xlabel='body'>

# %%
data.loc[(data.engV_bins == 'large')].groupby('body').agg({'body':'count'}).plot.bar()
# Out:
# <AxesSubplot:xlabel='body'>

# %%
pd.crosstab(data['engType'],data['engV_bins'])
# Out:
# engV_bins  small  medium  large
# engType
# Diesel      1430    1240     89
# Gas         1035     460    157
# Other        254      67     17
# Petrol      2918     793    446

# %%
data.loc[(data.engV_bins == 'small')].groupby('engType').agg({'price':'mean'}).plot.line()
# Out:
# <AxesSubplot:xlabel='engType'>

# %%
data.loc[(data.engV_bins == 'medium')].groupby('engType').agg({'price':'mean'}).plot.line()
# Out:
# <AxesSubplot:xlabel='engType'>

# %%
data.loc[(data.engV_bins == 'large')].groupby('engType').agg({'price':'mean'}).plot.line()
# Out:
# <AxesSubplot:xlabel='engType'>

# %%
data = data.drop(['car_category'],axis =1)

# %%
data = data.drop(['year'],axis =1)

# %%
data = data.drop(['car_brand_mean_price'],axis =1)

# %%
data = data.drop(['bins'],axis =1)

# %%
data = data.drop(['engV_bins'],axis =1)

# %%
sns.pairplot(data)

# %% [markdown]
# ---
# <a name = Section9></a>
# # **9. Summarization**
# ---

# %% [markdown]
# <a name = Section91></a>
# ### **9.1 Conclusion**
#
# - In this part you need to provide a conclusion about your overall analysis.
#
# - Write down some short points that you have observed so far.

# %%
# Summary Statistics

# %%
# Top 20% of the car brands have 80% share in the data.
# Top 10 cars in terms of average price are not in Top 20% in terms of count. We can estimate that (continued below)
# economical cars = 10%, premium cars = 57% and luxury cars = 33%
# Sedan is the most frequently available car followed by crossover which is approx. half of sedan, 
# followed by hatchback and van
# Crossover is the having highest average price after that second in the price list is other category
# Years_in_Service = 2022- 'Purchasin Year'
# Average 'Years in Service' = 15 years and 75% of vehicles less than 18 years
# price is inversely related to 'Years in service' and reaches a minimum value by around 40 years irrespective of 
# car_type(continued below) and then it is increasing
# mileage is inversely proportional to price till 500 miles where it reaches a minimum except few cases
# avg. mileage for used cars in least for crossover < hatchback < other  < vagon  < van
# engV has strongest direct correlation with pricing of the vehicle. Outliers are removed as most of the vehicles have (continued below)
# engV in the range of 0 to 6.5. 
# The cars have good 'engV' spread as there are cars of medium 'engV' (between 2 and 3.5) and there are cars of low (between 1 & 2) & high 'engV' (above 3.5) both.
# Crossovers have genreally large engV. Hatchbacks have small engV.
# engType is mostly petrol for sedan and hatchback where as vagon and van are mostly diesel based. 
# Mean price of gas based vehicles is nearly half price that of diesel based vehicles.
# Full drive vehicles are most expensive i.e. approx. 3 times as expensive as front drive vehicles.
# All body type vehicles are mostly front drive except crossover which are maximum are full drive.
# Bottom 25 percentile price brands have on an average 5 models per car, brands having price range in between (continued below) 
# 25 percentile and 75 percentile have on an average 11 models per car whereas above 75% percentile (continued below)
# have on an average 14 models per car.

# %% [markdown]
# <a name = Section92></a>
# ### **9.2 Actionable Insights**
#
# - This is a very crucial part where you will present your actionable insights.
# - You need to give suggestions about what could be applied and what not.
# - Make sure that these suggestions are short and to the point, ultimately it's a catalyst to your business.

# %%
# Actionable Insights

# %%
# i)
